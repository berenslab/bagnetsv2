# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path

cwd = Path.cwd().resolve()
if cwd.name == "notebooks":
    os.chdir(cwd.parent)

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.models import get_model

from bagnetsv2 import bagnets, utils

device = 'cuda:0'
utils.set_seed(42)

# %% [markdown]
# ### Load dataset and model

# %%
# Experiment arguments
backbone = 'bagnet33'
weights = 'DEFAULT'
n_classes = 10000
dataset = 'imagenet'
dataset_dir = 'datasets/ImageNet2012'
img_size = (224, 224)
batch_size = 128
num_workers = 4

# %%
# Load hold-out test set
transform = utils.get_augmentations(img_size, normalization=utils.IMAGENET_NORMALIZATION, imagenet=True)['test']
transform_orig = utils.get_augmentations(img_size, normalization=None, imagenet=True)['test'] # For the overlay of the heatmaps

if dataset == 'imagenet':
    dataset_test = datasets.ImageNet(dataset_dir, split='val', transform=transform)
    dataset_orig = datasets.ImageNet(dataset_dir, split='val', transform=transform_orig)
    n_classes = 1000
else:
    dataset_test = datasets.Imagenette('datasets', split='val', transform=transform, size='320px')
    dataset_orig = datasets.Imagenette('datasets', split='val', transform=transform_orig, size='320px')
    n_classes = 10

dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True, drop_last=True)
img_batch = dataset_test[0][0].unsqueeze(0).to(device) # Test image
img_label = dataset_test[0][1]

# %%
model = bagnets.get_bagnet(backbone, weights=weights, num_classes=1000)
# checkpoint = torch.load(checkpoint_file, map_location=torch.device('cpu'))
# state_dict = checkpoint['state_dict'] if isinstance(checkpoint, dict) else checkpoint
# model.load_state_dict(state_dict)
model.to(device)
model.eval();

# %% [markdown]
# ### 1. Bagnet prediction difference with TF32 vs F32

# %%
utils.set_tf32(True)
prediction_tf32 = model(img_batch)[0, img_label]
print(f'Prediction with tf32 = {prediction_tf32.item():.4f}')

utils.set_tf32(False)
prediction_fp32 = model(img_batch)[0, img_label]
print(f'Prediction with fp32 = {prediction_fp32.item():.4f}')

absolute_diff = (prediction_fp32 - prediction_tf32).abs()
print(f'Absolute difference = {absolute_diff.item():.3e}')

relative_diff = absolute_diff * 100 / prediction_tf32
print(f'Relative difference = {relative_diff.item():.2f}%')
# Out:
# Prediction with tf32 = 17.7340
# Prediction with fp32 = 16.3335
# Absolute difference = 1.400e+00
# Relative difference = 7.90%

# %% [markdown]
# ### 2. BagNet weight distribution

# %%
for name, parameters in model.named_parameters():
    if 'conv' in name:
        max_weight = parameters.flatten().abs().max()
        print(f'Maximum absolute value of the weights from layer {name} = {max_weight.item():.3e}')
# Out:
# Maximum absolute value of the weights from layer conv1.weight = 8.554e-01
# Maximum absolute value of the weights from layer conv2.weight = 6.369e-01
# Maximum absolute value of the weights from layer layer1.0.conv1.weight = 7.247e+00
# Maximum absolute value of the weights from layer layer1.0.conv2.weight = 4.254e-01
# Maximum absolute value of the weights from layer layer1.0.conv3.weight = 8.943e+00
# Maximum absolute value of the weights from layer layer1.1.conv1.weight = 8.108e-08
# Maximum absolute value of the weights from layer layer1.1.conv2.weight = 1.165e-07
# Maximum absolute value of the weights from layer layer1.1.conv3.weight = 1.049e-07
# Maximum absolute value of the weights from layer layer1.2.conv1.weight = 8.242e-08
# Maximum absolute value of the weights from layer layer1.2.conv2.weight = 9.762e-08
# Maximum absolute value of the weights from layer layer1.2.conv3.weight = 9.184e-08
# Maximum absolute value of the weights from layer layer2.0.conv1.weight = 4.534e-01
# Maximum absolute value of the weights from layer layer2.0.conv2.weight = 3.389e-01
# Maximum absolute value of the weights from layer layer2.0.conv3.weight = 5.052e-01
# Maximum absolute value of the weights from layer layer2.1.conv1.weight = 1.016e-07
# Maximum absolute value of the weights from layer layer2.1.conv2.weight = 1.720e-07
# Maximum absolute value of the weights from layer layer2.1.conv3.weight = 1.596e-07
# Maximum absolute value of the weights from layer layer2.2.conv1.weight = 6.473e-08
# Maximum absolute value of the weights from layer layer2.2.conv2.weight = 3.776e-07
# Maximum absolute value of the weights from layer layer2.2.conv3.weight = 3.575e-07
# Maximum absolute value of the weights from layer layer2.3.conv1.weight = 4.581e-08
# Maximum absolute value of the weights from layer layer2.3.conv2.weight = 1.383e-07
# Maximum absolute value of the weights from layer layer2.3.conv3.weight = 1.528e-07
# Maximum absolute value of the weights from layer layer3.0.conv1.weight = 9.104e-01
# Maximum absolute value of the weights from layer layer3.0.conv2.weight = 9.762e-01
# Maximum absolute value of the weights from layer layer3.0.conv3.weight = 4.679e-01
# Maximum absolute value of the weights from layer layer3.1.conv1.weight = 2.597e-01
# Maximum absolute value of the weights from layer layer3.1.conv2.weight = 4.936e-01
# Maximum absolute value of the weights from layer layer3.1.conv3.weight = 2.991e-01
# Maximum absolute value of the weights from layer layer3.2.conv1.weight = 3.101e-01
# Maximum absolute value of the weights from layer layer3.2.conv2.weight = 4.038e-01
# Maximum absolute value of the weights from layer layer3.2.conv3.weight = 4.671e-01
# Maximum absolute value of the weights from layer layer3.3.conv1.weight = 2.167e-06
# Maximum absolute value of the weights from layer layer3.3.conv2.weight = 6.854e-06
# Maximum absolute value of the weights from layer layer3.3.conv3.weight = 4.494e-06
# Maximum absolute value of the weights from layer layer3.4.conv1.weight = 2.161e-05
# Maximum absolute value of the weights from layer layer3.4.conv2.weight = 1.687e-04
# Maximum absolute value of the weights from layer layer3.4.conv3.weight = 1.717e-05
# Maximum absolute value of the weights from layer layer3.5.conv1.weight = 2.100e-05
# Maximum absolute value of the weights from layer layer3.5.conv2.weight = 1.994e-03
# Maximum absolute value of the weights from layer layer3.5.conv3.weight = 5.029e-05
# Maximum absolute value of the weights from layer layer4.0.conv1.weight = 3.957e-01
# Maximum absolute value of the weights from layer layer4.0.conv2.weight = 2.991e-01
# Maximum absolute value of the weights from layer layer4.0.conv3.weight = 4.626e-01
# Maximum absolute value of the weights from layer layer4.1.conv1.weight = 8.093e-01
# Maximum absolute value of the weights from layer layer4.1.conv2.weight = 6.308e-01
# Maximum absolute value of the weights from layer layer4.1.conv3.weight = 7.763e-01
# Maximum absolute value of the weights from layer layer4.2.conv1.weight = 1.016e+00
# Maximum absolute value of the weights from layer layer4.2.conv2.weight = 6.870e-01
# Maximum absolute value of the weights from layer layer4.2.conv3.weight = 7.115e-01

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 5))
for name, parameters in model.named_parameters():
    if 'conv' in name:
        params = parameters.detach().cpu().numpy().flatten()
        sns.kdeplot(x=params, ax=ax)

# ax.set_xlim([-2, 2])
ax.set_ylim([1e-10, 1e8])
ax.set_yscale('log')
ax.set_title('Bagnet weight distribution')
ax.set_xlabel('Weight Values')
plt.tight_layout()

# %% [markdown]
# ### 3. Bagnet Accuracy
# Different results are obtained when using FP32 vs TF32 vs FP16.

# %%
utils.set_tf32(True)
probs, targets = utils.predict(model, dataloader_test, device, autocast=False)

acc = utils.accuracy(torch.from_numpy(probs), torch.from_numpy(targets), (1, 5))
print(f'Top 1 accuracy on validation set (tf32): {acc[0].item():.2f}')
print(f'Top 5 accuracy on validation set (tf32): {acc[1].item():.2f}')

utils.set_tf32(False)
probs, targets = utils.predict(model, dataloader_test, device, autocast=False)

acc = utils.accuracy(torch.from_numpy(probs), torch.from_numpy(targets), (1, 5))
print(f'Top 1 accuracy on validation set (fp32): {acc[0].item():.2f}')
print(f'Top 5 accuracy on validation set (fp32): {acc[1].item():.2f}')
# Out:
# 100%|██████████| 390/390 [02:37<00:00,  2.47it/s]
# Top 1 accuracy on validation set (tf32): 64.23
# Top 5 accuracy on validation set (tf32): 85.31
# 100%|██████████| 390/390 [03:10<00:00,  2.04it/s]
# Top 1 accuracy on validation set (fp32): 66.70
# Top 5 accuracy on validation set (fp32): 87.00

# %% [markdown]
# ### 4. Comparison to Resnet

# %%
# Load resnet 50
model_resnet = get_model('resnet50', weights='DEFAULT')

model_resnet.to(device)
model_resnet.eval();

# %%
utils.set_tf32(True)
prediction_tf32 = model_resnet(img_batch)[0, img_label]
print(f'Prediction with tf32 = {prediction_tf32.item():.4f}')

utils.set_tf32(False)
prediction_fp32 = model_resnet(img_batch)[0, img_label]
print(f'Prediction with fp32 = {prediction_fp32.item():.4f}')

absolute_diff = (prediction_fp32 - prediction_tf32).abs()
print(f'Absolute difference = {absolute_diff.item():.3e}')

relative_diff = (prediction_fp32 - prediction_tf32).abs() * 100 / prediction_tf32
print(f'Relative difference = {relative_diff.item():.2f}%')
# Out:
# Prediction with tf32 = 6.7760
# Prediction with fp32 = 6.7687
# Absolute difference = 7.238e-03
# Relative difference = 0.11%

# %%
for name, parameters in model_resnet.named_parameters():
    if 'conv' in name:
        max_weight = parameters.flatten().abs().max()
        print(f'Maximum absolute value of the weights from layer {name} = {max_weight.item():.3e}')
# Out:
# Maximum absolute value of the weights from layer conv1.weight = 1.979e+00
# Maximum absolute value of the weights from layer layer1.0.conv1.weight = 1.513e+00
# Maximum absolute value of the weights from layer layer1.0.conv2.weight = 1.475e+00
# Maximum absolute value of the weights from layer layer1.0.conv3.weight = 1.352e+00
# Maximum absolute value of the weights from layer layer1.1.conv1.weight = 1.019e+00
# Maximum absolute value of the weights from layer layer1.1.conv2.weight = 9.823e-01
# Maximum absolute value of the weights from layer layer1.1.conv3.weight = 7.892e-01
# Maximum absolute value of the weights from layer layer1.2.conv1.weight = 5.133e-01
# Maximum absolute value of the weights from layer layer1.2.conv2.weight = 7.743e-01
# Maximum absolute value of the weights from layer layer1.2.conv3.weight = 8.039e-01
# Maximum absolute value of the weights from layer layer2.0.conv1.weight = 9.839e-01
# Maximum absolute value of the weights from layer layer2.0.conv2.weight = 4.567e-01
# Maximum absolute value of the weights from layer layer2.0.conv3.weight = 8.369e-01
# Maximum absolute value of the weights from layer layer2.1.conv1.weight = 5.148e-01
# Maximum absolute value of the weights from layer layer2.1.conv2.weight = 7.586e-01
# Maximum absolute value of the weights from layer layer2.1.conv3.weight = 8.381e-01
# Maximum absolute value of the weights from layer layer2.2.conv1.weight = 6.490e-01
# Maximum absolute value of the weights from layer layer2.2.conv2.weight = 8.606e-01
# Maximum absolute value of the weights from layer layer2.2.conv3.weight = 7.607e-01
# Maximum absolute value of the weights from layer layer2.3.conv1.weight = 5.396e-01
# Maximum absolute value of the weights from layer layer2.3.conv2.weight = 6.717e-01
# Maximum absolute value of the weights from layer layer2.3.conv3.weight = 6.675e-01
# Maximum absolute value of the weights from layer layer3.0.conv1.weight = 7.995e-01
# Maximum absolute value of the weights from layer layer3.0.conv2.weight = 5.471e-01
# Maximum absolute value of the weights from layer layer3.0.conv3.weight = 8.737e-01
# Maximum absolute value of the weights from layer layer3.1.conv1.weight = 7.600e-01
# Maximum absolute value of the weights from layer layer3.1.conv2.weight = 7.048e-01
# Maximum absolute value of the weights from layer layer3.1.conv3.weight = 9.448e-01
# Maximum absolute value of the weights from layer layer3.2.conv1.weight = 7.175e-01
# Maximum absolute value of the weights from layer layer3.2.conv2.weight = 5.678e-01
# Maximum absolute value of the weights from layer layer3.2.conv3.weight = 6.072e-01
# Maximum absolute value of the weights from layer layer3.3.conv1.weight = 6.577e-01
# Maximum absolute value of the weights from layer layer3.3.conv2.weight = 8.113e-01
# Maximum absolute value of the weights from layer layer3.3.conv3.weight = 5.874e-01
# Maximum absolute value of the weights from layer layer3.4.conv1.weight = 6.839e-01
# Maximum absolute value of the weights from layer layer3.4.conv2.weight = 4.979e-01
# Maximum absolute value of the weights from layer layer3.4.conv3.weight = 5.460e-01
# Maximum absolute value of the weights from layer layer3.5.conv1.weight = 5.949e-01
# Maximum absolute value of the weights from layer layer3.5.conv2.weight = 3.427e-01
# Maximum absolute value of the weights from layer layer3.5.conv3.weight = 5.161e-01
# Maximum absolute value of the weights from layer layer4.0.conv1.weight = 1.043e+00
# Maximum absolute value of the weights from layer layer4.0.conv2.weight = 6.552e-01
# Maximum absolute value of the weights from layer layer4.0.conv3.weight = 9.215e-01
# Maximum absolute value of the weights from layer layer4.1.conv1.weight = 6.408e-01
# Maximum absolute value of the weights from layer layer4.1.conv2.weight = 5.745e-01
# Maximum absolute value of the weights from layer layer4.1.conv3.weight = 5.613e-01
# Maximum absolute value of the weights from layer layer4.2.conv1.weight = 8.181e-01
# Maximum absolute value of the weights from layer layer4.2.conv2.weight = 7.966e-01
# Maximum absolute value of the weights from layer layer4.2.conv3.weight = 6.134e-01

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 5))
for name, parameters in model_resnet.named_parameters():
    if 'conv' in name:
        params = parameters.detach().cpu().numpy().flatten()
        sns.kdeplot(x=params, ax=ax)

ax.set_title('Resnet weight distribution')
ax.set_xlabel('Weight Values')
ax.set_xlim([-1, 1])
plt.tight_layout()

# %% [markdown]
# ### 5. Comparing all predictions from the validation set

# %%
# Change last layer to produce a single number
model.fc = nn.AdaptiveAvgPool1d(1)

# Load dataset
utils.set_tf32(True)
preds_tf32, _ = utils.predict_logits(model, dataloader_test, device, autocast=False)

utils.set_tf32(False)
preds_fp32, _ = utils.predict_logits(model, dataloader_test, device, autocast=False)

diff = preds_fp32 - preds_tf32
absolute_diff = np.abs(diff)
relative_diff = absolute_diff * 100 / preds_fp32

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

sns.kdeplot(x=preds_tf32, label='TF32', ax=ax[0])
sns.kdeplot(x=preds_fp32, label='FP32', ax=ax[0])
ax[0].legend()
ax[0].set_title('Predictions')

sns.kdeplot(x=diff, label='Difference', ax=ax[1])
sns.kdeplot(x=absolute_diff, label='Absolute difference', ax=ax[1])
ax[1].legend(loc='upper right')
ax[1].set_title('Difference (FP32 - TF32)')

sns.kdeplot(x=relative_diff, label='Relative difference (%)', ax=ax[2])
ax[2].set_title('Relative difference (FP32 - TF32) * 100% / FP32')
plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 1)
sns.scatterplot(x=preds_fp32, y=preds_tf32, alpha=0.8, s=5, marker='.', linewidths=None, edgecolors='None', ax=ax)
sns.lineplot(x=[0, 1], y=[0, 1], color='grey', linewidth=0.8, legend=False, ax=ax)
ax.set_xlabel('Prediction in FP32')
ax.set_ylabel('Prediction in TF32')
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.grid()
ax.set_title('TF32 vs FP32')
plt.tight_layout()

# %% [markdown]
# ### 6. Check intermediate outputs

# %%
# Load model again to get the last layer
model = bagnets.get_bagnet(backbone, weights=weights, num_classes=1000)
# checkpoint = torch.load(checkpoint_file, map_location=torch.device('cpu'))
# state_dict = checkpoint['state_dict'] if isinstance(checkpoint, dict) else checkpoint
# model.load_state_dict(state_dict)

for param in model.parameters():
    param.requires_grad = False

model.to(device)
model.eval();

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

model.layer1.register_forward_hook(get_activation('layer1'))

utils.set_tf32(True)
output = model(img_batch)
intermediate_fp32 = activation['layer1'].cpu().numpy().flatten()

utils.set_tf32(False)
output = model(img_batch)
intermediate_tf32 = activation['layer1'].cpu().numpy().flatten()

diff = intermediate_fp32 - intermediate_tf32
absolute_diff = np.abs(diff)
relative_diff = absolute_diff * 100 / intermediate_tf32
# Out:
# /tmp/ipykernel_701287/486237302.py:19: RuntimeWarning: divide by zero encountered in divide
#   relative_diff = absolute_diff * 100 / intermediate_tf32
# /tmp/ipykernel_701287/486237302.py:19: RuntimeWarning: invalid value encountered in divide
#   relative_diff = absolute_diff * 100 / intermediate_tf32

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

sns.kdeplot(x=intermediate_tf32, label='TF32', ax=ax[0])
sns.kdeplot(x=intermediate_fp32, label='FP32', ax=ax[0])
ax[0].legend()
ax[0].set_title('Intermediate output')

sns.kdeplot(x=diff, label='Difference', ax=ax[1])
sns.kdeplot(x=absolute_diff, label='Absolute difference', ax=ax[1])
ax[1].legend(loc='upper right')
ax[1].set_title('Difference (FP32 - TF32)')

sns.kdeplot(x=relative_diff, label='Relative difference (%)', ax=ax[2])
ax[2].set_title('Relative difference (FP32 - TF32) * 100% / FP32')
plt.tight_layout()

# %% [markdown]
# ### 7. BagNet: removing dead convolutional layers
# The predictions don't change when these layers are set to 0 which means they are having little to no influence in the output.

# %%
for name, parameters in model.named_parameters():
    if 'conv' in name:
        max_weight = parameters.flatten().abs().max()

        if max_weight <= 1e-4:
            parameters.zero_()

        max_weight = parameters.flatten().abs().max()
        # print(f'Maximum absolute value of the weights from layer {name} = {max_weight.item():.3e}')

# %%
utils.set_tf32(True)
prediction_tf32 = model(img_batch)[0, img_label]
print(f'Prediction with tf32 = {prediction_tf32.item():.4f}')

utils.set_tf32(False)
prediction_fp32 = model(img_batch)[0, img_label]
print(f'Prediction with fp32 = {prediction_fp32.item():.4f}')

absolute_diff = (prediction_fp32 - prediction_tf32).abs()
print(f'Absolute difference = {absolute_diff.item():.3e}')

relative_diff = (prediction_fp32 - prediction_tf32).abs() * 100 / prediction_tf32
print(f'Relative difference = {relative_diff.item():.2f}%')
# Out:
# Prediction with tf32 = 17.7340
# Prediction with fp32 = 16.3335
# Absolute difference = 1.400e+00
# Relative difference = 7.90%

# %% [markdown]
# ### 8. BagNet: removing dead convolutional layers + batch normalization bias

# %%
for name, parameters in model.named_parameters():
    if 'bn' and 'bias' in name:
        parameters.zero_()
        max_weight = parameters.flatten().abs().max()

        # print(f'Maximum absolute value of the weights from layer {name} = {max_weight.item():.3e}')

# %%
utils.set_tf32(True)
prediction_tf32 = model(img_batch)[0, img_label]
print(f'Prediction with tf32 = {prediction_tf32.item():.4f}')

utils.set_tf32(False)
prediction_fp32 = model(img_batch)[0, img_label]
print(f'Prediction with fp32 = {prediction_fp32.item():.4f}')

absolute_diff = (prediction_fp32 - prediction_tf32).abs()
print(f'Absolute difference = {absolute_diff.item():.3e}')

relative_diff = (prediction_fp32 - prediction_tf32).abs() * 100 / prediction_tf32
print(f'Relative difference = {relative_diff.item():.2f}%')
# Out:
# Prediction with tf32 = -2266.7893
# Prediction with fp32 = -2267.8010
# Absolute difference = 1.012e+00
# Relative difference = -0.04%

# %% [markdown]
# ### 9. Check heatmaps

# %%
# Load model again to get original weights
model = bagnets.get_bagnet(backbone, weights=weights, num_classes=1000)
# checkpoint = torch.load(checkpoint_file, map_location=torch.device('cpu'))
# state_dict = checkpoint['state_dict'] if isinstance(checkpoint, dict) else checkpoint
# model.load_state_dict(state_dict)

for param in model.parameters():
    param.requires_grad = False

model.to(device)
model.eval();

# %%
img_idx = np.random.randint(0, len(dataset_test))

img_orig = dataset_orig[img_idx][0]
img_batch = dataset_test[img_idx][0].unsqueeze(0).to(device)
img_label = dataset_test[img_idx][1]

model.avg_pool = False

fig, ax = plt.subplots(1, 2)
hm = model(img_batch).squeeze().cpu().detach().numpy()
ax[0].imshow(transforms.ToPILImage()(img_orig))
ax[0].set_axis_off()
ax[0].set_title(dataset_test.classes[img_label][0])

bagnets.plot_heatmap(hm[:, :, img_label], img_orig, fig, ax[1], percentile=99)
plt.tight_layout()
